# %% [markdown]
# # Simplification pipeline
#
# This is an abstracted simplification pipeline that can be used to resolve all artifacts.
#
# To deal with some minor consequences of simplification, we will need to run this twice, in some way.
#
# Also, it should be combined togehter to a single function that does not call `simplify_singletons`, `simplify_pairs`, and `simplify_clusters` in a sequence like this as there's some duplicated computation hapenning. But it works. Mostly.

# %%
import logging
import warnings

import folium
from libpysal import graph

from core import algorithms, utils

# %% [markdown]
# Filter out the RuntimeWarning showing on Apple Silicon.

# %%
warnings.filterwarnings(
    "ignore",
    category=RuntimeWarning,
    message="invalid value encountered in intersection",
)

# %% [markdown]
# Set logging level to debug to see the debugging messages.

# %%
# # Get the logger for core.algorithms.simplify
# logger = logging.getLogger('core.algorithms.simplify')
# logger.setLevel(logging.DEBUG)

# # Set the logging format
# formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# # Create a handler for the logger
# handler = logging.StreamHandler()
# handler.setLevel(logging.DEBUG)
# handler.setFormatter(formatter)

# # Add the handler to the logger
# logger.addHandler(handler)

# %% [markdown]
# Specify case metadata

# %%
case = "Bucaramanga"

# %% [markdown]
# Read road data

# %%
roads = utils.read_no_degree_2(case)

# %% [markdown]
# Merge nearby nodes (up to double of distance used in skeleton).

# %%
roads = algorithms.simplify.consolidate_nodes(roads, tolerance=2.1)

# %% [markdown]
# Identify artifacts

# %%
artifacts, _ = algorithms.simplify.get_artifacts(roads)

# %% [markdown]
# Remove edges fully within the artifact (dangles).

# %%
_, r_idx = roads.sindex.query(artifacts.geometry, predicate="contains")
roads = roads.drop(roads.index[r_idx])
roads = algorithms.simplify.remove_false_nodes(roads)

# %% [markdown]
# Filter singleton artifacts

# %%
rook = graph.Graph.build_contiguity(artifacts, rook=True)

# keep only those artifacts which occur as isolates, i.e. are not part of a larger intersection
singles = artifacts.loc[artifacts.index.intersection(rook.isolates)]

# %% [markdown]
# Filter doubles

# %%
artifacts["comp"] = rook.component_labels
counts = artifacts["comp"].value_counts()
doubles = artifacts.loc[artifacts["comp"].isin(counts[counts == 2].index)]

# %% [markdown]
# Filter clusters

# %%
clusters = artifacts.loc[artifacts["comp"].isin(counts[counts > 2].index)].copy()

# %% [markdown]
# Simplify artifacts.

# %%
new_roads = algorithms.simplify.simplify_singletons(singles, roads)
new_roads = algorithms.simplify.simplify_pairs(doubles, new_roads)
new_roads = algorithms.simplify.simplify_clusters(clusters, new_roads)

# %%
aplot = {
    "singles": singles,
    "doubles": doubles.drop_duplicates("comp"),
    "clusters": clusters.drop_duplicates("comp")
}

colors = {"iterate": "orange", "skeleton": "green", "drop_interline": "blue"}
aplot["singles"]["comp"] = aplot["singles"].index

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
for i, row in aplot["singles"].iterrows():
    
    # plot the results for visual verification
    geom = gpd.GeoSeries(row.geometry, crs = artifacts.crs)
    ax = new_roads.clip(geom.buffer(50)).plot(zorder=2, cmap="tab20")
    geom.plot(
        ax=ax,
        alpha=0.1,
    )
    roads.clip(geom.buffer(50)).plot(
        color="red",
        ax=ax,
        # categorical=True,
        # legend=True,
        linewidth=0.1,
    )
    ax.set_title("Singles (index:" + str(row.id) + ")")
    plt.show()

# %% [markdown]
# bucaramanga singles
# check on map:
# * 41 what happened to all the red lines around?
# * 3334 (will roundabout be picked up by next round?)
# * 4150 nothing happened?
# * 4436 should we discard disconnected components?

# %%
# for i, row in aplot["singles"].iterrows():
#     if i == 4436:
#         # plot the results for visual verification
#         fig, ax = plt.subplots(1,1, figsize = (20,20))
#         geom = gpd.GeoSeries(row.geometry, crs = artifacts.crs)
#         new_roads.clip(geom.buffer(50)).plot(ax=ax, zorder=2, cmap="tab20")
#         geom.plot(
#             ax=ax,
#             alpha=0.1,
#         )
#         roads.clip(geom.buffer(50)).plot(
#             color="red",
#             ax=ax,
#             # categorical=True,
#             # legend=True,
#             linewidth=0.1,
#         )
#         ax.set_title("Singles (index:" + str(row.id) + ")")
#         plt.show()

# %%
for artifact in aplot["doubles"].itertuples():
    
    # plot the results for visual verification
    geom = artifacts[artifacts.comp == artifact.comp]

    ax = new_roads.clip(geom.buffer(50)).plot(zorder=2, cmap="tab20")
    geom.plot(
        ax=ax,
        alpha=0.1,
    )
    roads.clip(geom.buffer(50)).plot(
        color="red",
        ax=ax,
        # categorical=True,
        # legend=True,
        linewidth=0.1,
    )
    ax.set_title("Doubles (comp:" + str(artifact.comp) + ")")
    plt.show()

# %%
for artifact in aplot["doubles"].itertuples():
    if artifact.comp == 130:
        fig, ax = plt.subplots(1,1, figsize = (20,20))
        # plot the results for visual verification
        geom = artifacts[artifacts.comp == artifact.comp]

        new_roads.clip(geom.buffer(50)).plot(ax=ax, zorder=2, cmap="tab20")
        geom.plot(
            ax=ax,
            alpha=0.1,
        )
        roads.clip(geom.buffer(50)).plot(
            color="red",
            ax=ax,
            # categorical=True,
            # legend=True,
            linewidth=0.1,
        )
        ax.set_title("Doubles (comp:" + str(artifact.comp) + ")")
        plt.show()

# %%
for artifact in aplot["clusters"].itertuples():
    
    # plot the results for visual verification
    geom = artifacts[artifacts.comp == artifact.comp]

    ax = new_roads.clip(geom.buffer(50)).plot(zorder=2, cmap="tab20")
    geom.plot(
        ax=ax,
        alpha=0.1,
    )
    roads.clip(geom.buffer(50)).plot(
        color="red",
        ax=ax,
        # categorical=True,
        # legend=True,
        linewidth=0.1,
    )
    ax.set_axis_off()
    ax.set_title("Clusters (comp:" + str(artifact.comp) + ")")
    plt.show()

# %% [markdown]
# bucaramanga clusters
# 13, 14: node merge?
#
# 15, 25, 34, 85, 86, 103, 104, 116,  check on explore map
#
# 264: missing dangle?

# %%
mycluster = 116
m = roads.explore(
    max_zoom=52,
    tiles="cartodb positron",
    color="black",
    prefer_canvas=True,
    name = "roads",
    style_kwds={"weight":0.5}
)

new_roads.explore(m=m, name = "new roads", color = "purple", style_kwds={"weight":2})

# singles.explore(m=m, color="orange", opacity = .2, name = "singles")
# doubles.explore(m=m, color="red", opacity = .3, name = "doubles")
clusters[clusters.comp==mycluster].explore(m=m, opacity = .8, name = f"cluster {mycluster}", color = "yellow")

folium.LayerControl().add_to(m)
m
