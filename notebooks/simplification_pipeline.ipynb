# %% [markdown]
# # Simplification pipeline
#
# This is an abstracted simplification pipeline that can be used to resolve all artifacts.
#
# To deal with some minor consequences of simplification, we will need to run this twice, in some way.
#
# Also, it should be combined togehter to a single function that does not call `simplify_singletons`, `simplify_pairs`, and `simplify_clusters` in a sequence like this as there's some duplicated computation hapenning. But it works. Mostly.

# %%
import logging
import warnings

import folium
from libpysal import graph

from core import algorithms, utils

import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# Filter out the RuntimeWarning showing on Apple Silicon.

# %%
warnings.filterwarnings(
    "ignore",
    category=RuntimeWarning,
    message="invalid value encountered in intersection",
)

# %% [markdown]
# Set logging level to debug to see the debugging messages.

# %%
# # Get the logger for core.algorithms.simplify
# logger = logging.getLogger('core.algorithms.simplify')
# logger.setLevel(logging.DEBUG)

# # Set the logging format
# formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# # Create a handler for the logger
# handler = logging.StreamHandler()
# handler.setLevel(logging.DEBUG)
# handler.setFormatter(formatter)

# # Add the handler to the logger
# logger.addHandler(handler)

# %% [markdown]
# Specify case metadata

# %%
case = "Liège"

# %% [markdown]
# Read road data

# %%
roads = utils.read_no_degree_2(case)

# %% [markdown]
# Merge nearby nodes (up to double of distance used in skeleton).

# %%
roads = algorithms.simplify.consolidate_nodes(roads, tolerance=4)

# %% [markdown]
# Identify artifacts

# %%
artifacts = algorithms.simplify.get_artifacts(roads)

# %% [markdown]
# Remove edges fully within the artifact (dangles).

# %%
a_idx, _ = roads.sindex.query(artifacts.geometry, predicate="contains")
artifacts = artifacts.drop(artifacts.index[a_idx])

# %% [markdown]
# Filter singleton artifacts

# %%
rook = graph.Graph.build_contiguity(artifacts, rook=True)

# keep only those artifacts which occur as isolates, i.e. are not part of a larger intersection
singles = artifacts.loc[artifacts.index.intersection(rook.isolates)].copy()

# %% [markdown]
# Filter doubles

# %%
artifacts["comp"] = rook.component_labels
counts = artifacts["comp"].value_counts()
doubles = artifacts.loc[artifacts["comp"].isin(counts[counts == 2].index)].copy()

# %% [markdown]
# Filter clusters

# %%
clusters = artifacts.loc[artifacts["comp"].isin(counts[counts > 2].index)].copy()

# %% [markdown]
# Simplify artifacts.

# %%
new_roads_singles = algorithms.simplify.simplify_singletons(singles, roads)
new_roads_doubles = algorithms.simplify.simplify_pairs(doubles, new_roads_singles)
new_roads_clusters = algorithms.simplify.simplify_clusters(clusters, new_roads_doubles)

# %%
aplot = {
    "singles": singles,
    "doubles": doubles.drop_duplicates("comp"),
    "clusters": clusters.drop_duplicates("comp")
}

colors = {"iterate": "orange", "skeleton": "green", "drop_interline": "blue"}
aplot["singles"]["comp"] = aplot["singles"].index

# %% [markdown]
# print out all singles

# %%
for i, row in aplot["singles"].iterrows():
    
    print(row.id)

    # plot the results for visual verification
    geom = gpd.GeoSeries(row.geometry, crs = artifacts.crs)
    ax = new_roads_singles.clip(geom.buffer(50)).plot(zorder=2, cmap="tab20")
    geom.plot(
        ax=ax,
        alpha=0.1,
    )
    roads.clip(geom.buffer(50)).plot(
        color="red",
        ax=ax,
        # categorical=True,
        # legend=True,
        linewidth=0.1,
    )
    ax.set_axis_off()
    ax.set_title("Singles (index:" + str(row.id) + ")")
    plt.show()

# %% [markdown]
# print out all doubles

# %%
for artifact in aplot["doubles"].itertuples():
    
    # plot the results for visual verification
    geom = artifacts[artifacts.comp == artifact.comp]

    ax = new_roads_doubles.clip(geom.buffer(50)).plot(zorder=2, cmap="tab20")
    geom.plot(
        ax=ax,
        alpha=0.1,
    )
    roads.clip(geom.buffer(50)).plot(
        color="red",
        ax=ax,
        # categorical=True,
        # legend=True,
        linewidth=0.1,
    )
    ax.set_axis_off()
    ax.set_title("Doubles (comp:" + str(artifact.comp) + ")")
    plt.show()

# %% [markdown]
# print out all clusters

# %%
for artifact in aplot["clusters"].itertuples():
    
    # plot the results for visual verification
    geom = artifacts[artifacts.comp == artifact.comp]

    ax = new_roads_clusters.clip(geom.buffer(50)).plot(zorder=2, cmap="tab20")
    geom.plot(
        ax=ax,
        alpha=0.1,
    )
    roads.clip(geom.buffer(50)).plot(
        color="red",
        ax=ax,
        # categorical=True,
        # legend=True,
        linewidth=0.1,
    )
    ax.set_axis_off()
    ax.set_title("Clusters (comp:" + str(artifact.comp) + ")")
    plt.show()

# %%
m = roads.explore(
    max_zoom=52,
    tiles="cartodb positron",
    color="black",
    prefer_canvas=True,
    name = "roads",
    style_kwds={"weight":0.5}
)
# new_roads_singles.explore(m=m, name = "new_roads_singles", color = "blue", style_kwds={"weight":0.75})
# new_roads_doubles.explore(m=m, name = "new_roads_doubles", color = "black", style_kwds={"weight":0.75})
new_roads_clusters.explore(m=m, name = "new_roads_clusters", color = "purple", style_kwds={"weight":2})

# singles.explore(m=m, color="orange", opacity = .2, name = "singles")
# doubles.explore(m=m, color="red", opacity = .3, name = "doubles")
clusters[clusters.comp.isin([5, 9, 232])].explore(m=m, opacity = .8, name = "clusters", color = "yellow")

folium.LayerControl().add_to(m)
m

# %% [markdown]
# # Check whether roundabouts get detected:
#
# roundabouts next to single indeces...
# * 16
# * 155
# * 192
# * 601
#
# next to doubles comps...
# * 197
#
# next to clusters...
# * 305
