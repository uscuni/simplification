# %% [markdown]
# # VIZ for statistical comparison of errors

# %%
import os
import warnings

import geopandas as gpd
import matplotlib.pyplot as plt
import momepy as mm
import numpy as np
import pandas as pd
import scipy.stats

from core import stats, utils

# %%
methods_to_compare = [
    "original",
    "cityseer",
    "osmnx",
    "parenx-voronoi",
    "parenx-skeletonize",
    "neatnet",
]

eval_vars = [
    "avg_degree",
    "coordinate_count",
    "edge_count",
    "edge_length",
    "stroke_count",
    "stroke_length_max",
    "stroke_length_sum",
]

# %% [markdown]
# Read in "combined" table from `statistical_comparison.ipynb`

# %%
combined = pd.read_csv("combined.csv")
combined = combined.set_index(["variable", "case"]).sort_index(level=0)
combined.head(3)
# Out:
#                         original  cityseer     osmnx  parenx-voronoi  \
# variable   case
# avg_degree Aleppo       0.683894  0.818360  0.732887        0.851845
#            Auckland     0.439375  0.699569  0.498237        0.745444
#            Bucaramanga  0.676782  0.758940  0.697984        0.868573
#
#                         parenx-skeletonize   neatnet
# variable   case
# avg_degree Aleppo                 0.774428  0.912391
#            Auckland               0.709857  0.804845
#            Bucaramanga            0.834364  0.911900

# %% [markdown]
# Make dicts for plotting

# %%
cities = list(utils.city_fua.keys())
xpos = dict(zip(cities, range(len(cities)), strict=False))

# %% [markdown]
# ## Plot correlations

# %%
title_mapping = {
    "avg_degree": "Avg. degree",
    "coordinate_count": "Coordinate count",
    "edge_count": "Edge count",
    "edge_length": "Edge length",
    "stroke_count": "Stroke count",
    "stroke_length_max": "Stroke length (max)",
    "stroke_length_sum": "Stroke length (sum)",
}

# %%
fig, axs = plt.subplots(2, 4, sharex=True, sharey=True, figsize=(12, 6))

for i, metric in enumerate(eval_vars):
    ax = axs.flat[i]

    for method in methods_to_compare:
        ax.plot(
            combined.loc[metric][method],
            color=utils.method_color[method],
            linewidth=1,
            linestyle="dashed",
            marker="o",
            markersize=5,
            label=method,
        )
    ax.set_ylim(0, 1)
    if i == 6:
        ax.legend(loc="upper left", bbox_to_anchor=(1.15, 1.05), frameon=False)
    if i in range(4, 7):
        ax.set_xticks(list(xpos.values()))
        ax.set_xticklabels(list(xpos.keys()), rotation=90)
        # ax.set_xlabel("City")
    if i in [0, 4]:
        ax.set_ylabel(r"$\xi$ correlation")
    ax.set_title(title_mapping[metric])
    ax.spines[["right", "top"]].set_visible(False)
axs.flat[-1].remove()
plt.savefig("../../evaluation/chi.png", dpi=300, transparent=True, bbox_inches="tight")

# %% [markdown]
# ## Deltas

# %%
combined = pd.read_csv("combined_deltas.csv")
combined = combined.set_index(["variable", "case"]).sort_index(level=0)
combined.head(3)
# Out:
#                         original  cityseer  osmnx  parenx-voronoi  \
# variable   case
# avg_degree Aleppo          85.59     31.67  58.65           32.94
#            Auckland        33.70     17.34  25.11           19.16
#            Bucaramanga     65.62     27.13  59.54           20.66
#
#                         parenx-skeletonize  neatnet
# variable   case
# avg_degree Aleppo                    35.89    22.85
#            Auckland                  19.29    18.40
#            Bucaramanga               21.91    15.97

# %%
fig, axs = plt.subplots(2, 4, sharex=True, sharey=False, figsize=(12, 6))

for i, metric in enumerate(eval_vars):
    ax = axs.flat[i]
    if metric in ["coordinate_count", "edge_count"]:
        ax.set_yscale("log")

    if metric == "edge_length":
        ax.set_yticks([10000, 20000, 30000], labels=["10k", "20k", "30k"])

    if metric in ["stroke_length_max", "stroke_length_sum"]:
        ax.yaxis.offsetText.set_position((-0.1, 0))

    for method in methods_to_compare:
        ax.plot(
            combined.loc[metric][method],
            color=utils.method_color[method],
            linewidth=1,
            linestyle="dashed",
            marker="o",
            markersize=5,
            label=method,
        )
    # ax.set_ylim(0, 1)
    if i == 6:
        ax.legend(loc="upper left", bbox_to_anchor=(1.15, 1.05), frameon=False)
    if i in range(4, 7):
        ax.set_xticks(list(xpos.values()))
        ax.set_xticklabels(list(xpos.keys()), rotation=90)
        # ax.set_xlabel("City")
    if i in [0, 4]:
        ax.set_ylabel(r"$d$")
    ax.set_title(title_mapping[metric])
    ax.spines[["right", "top"]].set_visible(False)
axs.flat[-1].remove()
plt.savefig(
    "../../evaluation/delta.png", dpi=300, transparent=True, bbox_inches="tight"
)

# %% [markdown]
# ## Pearson

# %%
combined = pd.read_csv("combined_pearson.csv")
combined = combined.set_index(["variable", "case"]).sort_index(level=0)
combined.head(3)
# Out:
#                         original  cityseer     osmnx  parenx-voronoi  \
# variable   case
# avg_degree Aleppo       0.620850  0.954780  0.840054        0.948148
#            Auckland     0.548425  0.903479  0.739799        0.868067
#            Bucaramanga  0.483280  0.916765  0.597918        0.947446
#
#                         parenx-skeletonize   neatnet
# variable   case
# avg_degree Aleppo                 0.936231  0.974892
#            Auckland               0.862801  0.884705
#            Bucaramanga            0.939058  0.968384

# %%
fig, axs = plt.subplots(2, 4, sharex=True, sharey=True, figsize=(12, 6))

for i, metric in enumerate(eval_vars):
    ax = axs.flat[i]

    for method in methods_to_compare:
        ax.plot(
            combined.loc[metric][method],
            color=utils.method_color[method],
            linewidth=1,
            linestyle="dashed",
            marker="o",
            markersize=5,
            label=method,
        )
    ax.set_ylim(0, 1)
    if i == 6:
        ax.legend(loc="upper left", bbox_to_anchor=(1.15, 1.05), frameon=False)
    if i in range(4, 7):
        ax.set_xticks(list(xpos.values()))
        ax.set_xticklabels(list(xpos.keys()), rotation=90)
        # ax.set_xlabel("City")
    if i in [0, 4]:
        ax.set_ylabel(r"$\xi$ correlation")
    ax.set_title(title_mapping[metric])
    ax.spines[["right", "top"]].set_visible(False)
axs.flat[-1].remove()
plt.savefig(
    "../../evaluation/pearson.png", dpi=300, transparent=True, bbox_inches="tight"
)

# %% [markdown]
# ## Spearman

# %%
combined = pd.read_csv("combined_spearman.csv")
combined = combined.set_index(["variable", "case"]).sort_index(level=0)
combined.head(3)
# Out:
#                         original  cityseer     osmnx  parenx-voronoi  \
# variable   case
# avg_degree Aleppo       0.806864  0.945026  0.876560        0.944608
#            Auckland     0.753026  0.882039  0.787352        0.886927
#            Bucaramanga  0.710903  0.909040  0.726524        0.947549
#
#                         parenx-skeletonize   neatnet
# variable   case
# avg_degree Aleppo                 0.909743  0.971484
#            Auckland               0.878282  0.906347
#            Bucaramanga            0.937426  0.969387

# %%
fig, axs = plt.subplots(2, 4, sharex=True, sharey=True, figsize=(12, 6))

for i, metric in enumerate(eval_vars):
    ax = axs.flat[i]

    for method in methods_to_compare:
        ax.plot(
            combined.loc[metric][method],
            color=utils.method_color[method],
            linewidth=1,
            linestyle="dashed",
            marker="o",
            markersize=5,
            label=method,
        )
    ax.set_ylim(0, 1)
    if i == 6:
        ax.legend(loc="upper left", bbox_to_anchor=(1.15, 1.05), frameon=False)
    if i in range(4, 7):
        ax.set_xticks(list(xpos.values()))
        ax.set_xticklabels(list(xpos.keys()), rotation=90)
        # ax.set_xlabel("City")
    if i in [0, 4]:
        ax.set_ylabel(r"$\xi$ correlation")
    ax.set_title(title_mapping[metric])
    ax.spines[["right", "top"]].set_visible(False)
axs.flat[-1].remove()
plt.savefig(
    "../../evaluation/spearman.png", dpi=300, transparent=True, bbox_inches="tight"
)
